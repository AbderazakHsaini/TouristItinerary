# %%
import gurobipy as gp
from gurobipy import GRB

# %%
# === Sets ===
A_s = [0, 1, 2, 3, 4, 5]                                                # Locations (0 is hub)
T = [1, 2]                                                              # Days
V = ['car', 'bike', 'e_bike', 'scooter', 'walk']                        # Vehicle types
H = list(range(8, 21))                                                  # Hours of the day  

# === Parameters ===
# Daily time limits by vehicle per hour
Q_h = {
    h: {
        'car': 3,
        'bike': 5,
        'e_bike': 5,
        'scooter': 4,
        'walk': 6
    } for h in H
}

cost_rate_v = {
    'car': 10,
    'bike': 5,
    'e_bike': 3,
    'scooter': 4,
    'walk': 0
}

# day based costs, people based costs

# Travel times per vehicle
vehicle_travel_time = {
    'car': 1,
    'bike': 2,
    'e_bike': 1.5,
    'scooter': 1.8,
    'walk': 4
}

t_ij_s_v = {}

for v, time_per_unit in vehicle_travel_time.items():
    for i in A_s:
        for j in A_s:
            if i != j:
                t_ij_s_v[(i, j, v)] = time_per_unit

# Visit times per vehicle
tv_j_s_v = {(j, v): 1 for j in A_s for v in V}
for v in V:
    tv_j_s_v[(0, v)] = 0  # depot has no service time

# Availability for a location at a given time for a given vehicle
open_j_h_v = {}

poi_open_hours = {
    1: (9, 17),
    2: (9, 17),
    3: (9, 17),
    4: (10, 16),
    5: (11, 15)
}

for j in A_s:
    for h in H:
        for v in V:
            if j == 0:
                open_j_h_v[(j, h, v)] = 1  # depot always open
            elif j in poi_open_hours:
                start, end = poi_open_hours[j]
                open_j_h_v[(j, h, v)] = 1 if start <= h < end else 0
            else:
                open_j_h_v[(j, h, v)] = 0  # default closed

# %%
# === Compute q_j for each j: average t_{i→j} over all i plus service time at j ===
q_j = {}
for j in A_s:
    # collect all travel times into j (across all vehicles if multimodal; here single 'car')
    incoming = [
        t_ij_s_v[(i, j, v)]
        for i in A_s for v in V
        if i != j and (i, j, v) in t_ij_s_v
    ]
    if incoming:
        avg_travel = sum(incoming) / len(incoming)
        # service time at j: pick any vehicle (service is vehicle-specific)
        # here: tv_j_s_v[(j, v)] is the same for all v
        svc = tv_j_s_v[(j, V[0])]
        q_j[j] = avg_travel + svc
    else:
        q_j[j] = 0.0   # depot or isolated node

# %%
# === Model ===
model = gp.Model("MultimodalVehicleRouting")

# === Variables ===
x = model.addVars(A_s, A_s, T, H, V, vtype=GRB.BINARY, name="x")
X = model.addVars(T, H, V, vtype=GRB.INTEGER, name="X")  # Trips from depot per vehicle
u = model.addVars(A_s, H, V, vtype=GRB.CONTINUOUS, name="u")
z = model.addVars(T, H, V, vtype=GRB.BINARY, name="z")  # is vehicle currently active

# === Objective ===
lambda_cost = 0.001  # smaller penalty

visit_reward = 10    # scale up visits to balance cost scale

model.setObjective(
    gp.quicksum(
        x[i, j, t, h, v] * visit_reward
        for i in A_s for j in A_s
        for t in T for h in H for v in V
        if i != j and (i, j, v) in t_ij_s_v
    )
    - lambda_cost * gp.quicksum(
        x[i, j, t, h, v] * t_ij_s_v[i, j, v] * cost_rate_v[v]
        for i in A_s for j in A_s
        for t in T for h in H for v in V
        if i != j and (i, j, v) in t_ij_s_v
    ),
    GRB.MAXIMIZE
)

""" future priority system objective
priority = {1: 5, 2: 3, 3: 4}
model.setObjective(
    gp.quicksum(x[i, j, t, h, v] * priority.get(j, 1)
                for i in A_s for j in A_s for t in T for h in H for v in V
                if i != j and (i, j, v) in t_ij_s_v),
    GRB.MAXIMIZE
)
"""
# Out:
# ' future priority system objective\npriority = {1: 5, 2: 3, 3: 4}\nmodel.setObjective(\n    gp.quicksum(x[i, j, t, h, v] * priority.get(j, 1)\n                for i in A_s for j in A_s for t in T for h in H for v in V\n                if i != j and (i, j, v) in t_ij_s_v),\n    GRB.MAXIMIZE\n)\n'

# %%
# === Constraints ===

# No self-loops
model.addConstrs(
    (gp.quicksum(x[i, i, t, h, v] for t in T for h in H for v in V) == 0 for i in A_s),
    name="NoSelfLoops"
)

# Flow conservation
model.addConstrs((
    gp.quicksum(x[i, j, t, h, v] for i in A_s if (i, j, v) in t_ij_s_v) ==
    gp.quicksum(x[j, k, t, h, v] for k in A_s if (j, k, v) in t_ij_s_v)
    for j in A_s for t in T for h in H for v in V), name="FlowConservation"
)

# One visit per node (excluding depot)
model.addConstrs((
    gp.quicksum(x[i, j, t, h, v] 
                for t in T for h in H for v in V for i in A_s 
                if i != j and (i, j, v) in t_ij_s_v) <= 1
    for j in A_s if j != 0), name="OneVisit"
)

# Depot departure matches X[t, v]
model.addConstrs((
    gp.quicksum(x[0, j, t, h, v] 
                for j in A_s if j != 0 and (0, j, v) in t_ij_s_v) == X[t, h, v]
    for t in T for h in H for v in V), name="DepotStarts"
)

# Time budget constraint for each vehicle per day
model.addConstrs((
    gp.quicksum(x[i, j, t, h, v] * (t_ij_s_v[i, j, v] + tv_j_s_v[j, v])
                for i in A_s for j in A_s if i != j and (i, j, v) in t_ij_s_v) <= Q_h[h][v]
    for t in T for h in H for v in V), name="TimeBudget"
)

# Monotonicity: Xt,v ≥ Xt+1,v
model.addConstrs((
    X[t1, h, v] >= X[t2, h, v]
    for t1, t2 in zip(T[:-1], T[1:]) for h in H for v in V
), name="MonotonicTrips")

# Availability (based on opening hours)
model.addConstrs((
    x[i, j, t, h, v] <= open_j_h_v[j, h, v]
    for i in A_s for j in A_s for t in T for h in H for v in V if (i, j, v) in t_ij_s_v
), name="Availability"
)

model.addConstrs(
    (
        x[i, j, t, h, v] <= z[t, h, v]
        for i in A_s for j in A_s for t in T for h in H for v in V
        if i != j and (i, j, v) in t_ij_s_v
    ),
    name="ArcImpliesVehicleUse"
)

model.addConstrs(
    (
        gp.quicksum(z[t, h, v] for h in H) <= 3  # or any per-day limit
        for t in T for v in V
    ),
    name="MaxHoursPerVehicle"
)

model.addConstrs((
        gp.quicksum(z[t, h, v] for v in V) <= 1
        for t in T for h in H
    ),
    name="OnlyOneVehiclePerHour"
)

# Sub-tour Elimination Constraints (MTZ-like)
model.addConstrs((
    u[i, h, v] - u[j, h, v] + Q_h[h][v] * (1 - x[i, j, t, h, v]) >= 0
    for i in A_s for j in A_s if i != j 
    for t in T for h in H for v in V if (i, j, v) in t_ij_s_v
), name="MTZ1"
)

model.addConstrs((
    u[j, h, v] >= t_ij_s_v[i, j, v]
    for i in A_s for j in A_s if j != 0 
    for t in T for h in H for v in V if (i, j, v) in t_ij_s_v
), name="MTZ2"
)

model.addConstrs((
    u[i, h, v] <= Q_h[h][v]
    for i in A_s for h in H for v in V
), name="MaxTime"
)
# Out:
# {(0, 8, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 8, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 8, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 8, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 8, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 9, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 9, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 9, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 9, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 9, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 10, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 10, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 10, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 10, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 10, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 11, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 11, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 11, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 11, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 11, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 12, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 12, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 12, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 12, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 12, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 13, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 13, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 13, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 13, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 13, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 14, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 14, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 14, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 14, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 14, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 15, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 15, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 15, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 15, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 15, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 16, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 16, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 16, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 16, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 16, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 17, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 17, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 17, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 17, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 17, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 18, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 18, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 18, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 18, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 18, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 19, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 19, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 19, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 19, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 19, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 20, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 20, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 20, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 20, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 20, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 8, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 8, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 8, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 8, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 8, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 9, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 9, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 9, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 9, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 9, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 10, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 10, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 10, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 10, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 10, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 11, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 11, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 11, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 11, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 11, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 12, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 12, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 12, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 12, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 12, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 13, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 13, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 13, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 13, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 13, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 14, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 14, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 14, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 14, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 14, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 15, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 15, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 15, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 15, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 15, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 16, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 16, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 16, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 16, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 16, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 17, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 17, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 17, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 17, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 17, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 18, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 18, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 18, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 18, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 18, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 19, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 19, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 19, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 19, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 19, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 20, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 20, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 20, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 20, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 20, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 8, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 8, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 8, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 8, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 8, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 9, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 9, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 9, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 9, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 9, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 10, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 10, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 10, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 10, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 10, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 11, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 11, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 11, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 11, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 11, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 12, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 12, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 12, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 12, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 12, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 13, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 13, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 13, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 13, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 13, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 14, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 14, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 14, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 14, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 14, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 15, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 15, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 15, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 15, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 15, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 16, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 16, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 16, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 16, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 16, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 17, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 17, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 17, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 17, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 17, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 18, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 18, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 18, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 18, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 18, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 19, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 19, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 19, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 19, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 19, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 20, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 20, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 20, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 20, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 20, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 8, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 8, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 8, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 8, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 8, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 9, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 9, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 9, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 9, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 9, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 10, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 10, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 10, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 10, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 10, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 11, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 11, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 11, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 11, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 11, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 12, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 12, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 12, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 12, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 12, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 13, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 13, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 13, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 13, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 13, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 14, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 14, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 14, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 14, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 14, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 15, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 15, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 15, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 15, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 15, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 16, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 16, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 16, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 16, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 16, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 17, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 17, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 17, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 17, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 17, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 18, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 18, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 18, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 18, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 18, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 19, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 19, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 19, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 19, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 19, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 20, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 20, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 20, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 20, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 20, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 8, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 8, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 8, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 8, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 8, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 9, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 9, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 9, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 9, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 9, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 10, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 10, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 10, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 10, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 10, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 11, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 11, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 11, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 11, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 11, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 12, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 12, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 12, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 12, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 12, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 13, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 13, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 13, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 13, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 13, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 14, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 14, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 14, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 14, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 14, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 15, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 15, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 15, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 15, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 15, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 16, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 16, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 16, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 16, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 16, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 17, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 17, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 17, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 17, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 17, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 18, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 18, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 18, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 18, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 18, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 19, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 19, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 19, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 19, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 19, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 20, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 20, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 20, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 20, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (4, 20, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 8, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 8, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 8, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 8, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 8, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 9, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 9, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 9, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 9, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 9, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 10, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 10, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 10, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 10, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 10, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 11, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 11, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 11, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 11, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 11, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 12, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 12, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 12, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 12, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 12, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 13, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 13, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 13, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 13, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 13, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 14, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 14, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 14, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 14, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 14, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 15, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 15, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 15, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 15, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 15, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 16, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 16, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 16, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 16, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 16, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 17, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 17, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 17, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 17, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 17, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 18, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 18, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 18, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 18, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 18, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 19, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 19, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 19, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 19, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 19, 'walk'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 20, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 20, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 20, 'e_bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 20, 'scooter'): <gurobi.Constr *Awaiting Model Update*>,
#  (5, 20, 'walk'): <gurobi.Constr *Awaiting Model Update*>}

# %%
# === Solve ===
model.optimize()
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 24.4.0 24E263)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 16492 rows, 5330 columns and 43940 nonzeros
# Model fingerprint: 0xc68f0b8b
# Variable types: 390 continuous, 4940 integer (4810 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+01, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 15801 rows and 4744 columns
# Presolve time: 0.07s
# Presolved: 691 rows, 586 columns, 4728 nonzeros
# Variable types: 42 continuous, 544 integer (544 binary)
# Found heuristic solution: objective 99.9220000
#
# Root relaxation: objective 9.995500e+01, 152 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      99.9550000   99.95500  0.00%     -    0s
#
# Explored 1 nodes (152 simplex iterations) in 0.10 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 99.955 99.922 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.995500000000e+01, best bound 9.995500000000e+01, gap 0.0000%

# %%
# === Output All Trips ===
if model.status == GRB.OPTIMAL:
    print(f"\n✅ Optimal Objective Value: {model.objVal:.2f}\n")
    for t in T:
        for h in H:
            for v in V:
                # collect selected arcs
                arcs = [(i, j) for i in A_s for j in A_s
                        if i != j and (i, j, v) in t_ij_s_v and x[i, j, t, h, v].X > 0.5]

                if not arcs:
                    continue

                print(f"Day {t} @ {h:02d}:00, with Vehicle {v}:")

                # build mapping of successors and predecessors
                succ = {i: j for i, j in arcs}
                pred = {j: i for i, j in arcs}

                # find all starting points (0 → j arcs)
                starts = [j for i, j in arcs if i == 0]

                # reconstruct all routes starting from depot
                used = set()
                for start in starts:
                    if start in used:
                        continue

                    route = [0, start]
                    curr = start
                    used.add(0)
                    used.add(start)

                    while curr in succ and succ[curr] != 0 and succ[curr] not in used:
                        curr = succ[curr]
                        route.append(curr)
                        used.add(curr)

                    # end at depot if possible
                    if curr in succ and succ[curr] == 0:
                        route.append(0)
                        used.add(0)

                    route_str = " → ".join(str(n) for n in route)
                    print(f"  {route_str}")
else:
    print("❌ No optimal solution found.")

## only end at home at the end of the day
# Out:
# ✅ Optimal Objective Value: 99.95
#
# Day 1 @ 10:00, with Vehicle e_bike:
#   0 → 2 → 0
# Day 1 @ 13:00, with Vehicle e_bike:
#   0 → 5 → 0
# Day 1 @ 15:00, with Vehicle e_bike:
#   0 → 4 → 0
# Day 2 @ 10:00, with Vehicle e_bike:
#   0 → 1 → 0
# Day 2 @ 13:00, with Vehicle e_bike:
#   0 → 3 → 0
