# %%
import gurobipy as gp
from gurobipy import GRB

# %%
# === Sets ===
A_s = [0, 1, 2, 3]       # Locations (0 is hub)
T = [1, 2]               # Days
V = ['car', 'bike']      # Vehicle types

# === Parameters ===
Q_v = {'car': 5, 'bike': 20}  # Daily time limits by vehicle

# Travel times per vehicle
t_ij_s_v = {
    (0, 1, 'car'): 1, (0, 2, 'car'): 1, (0, 3, 'car'): 1,
    (1, 0, 'car'): 1, (2, 0, 'car'): 1, (3, 0, 'car'): 1,
    (1, 2, 'car'): 0.5, (1, 3, 'car'): 0.5, (2, 3, 'car'): 0.5,
    (2, 1, 'car'): 0.5, (3, 1, 'car'): 0.5, (3, 2, 'car'): 0.5,

    (0, 1, 'bike'): 2, (0, 2, 'bike'): 2, (0, 3, 'bike'): 2,
    (1, 0, 'bike'): 2, (2, 0, 'bike'): 2, (3, 0, 'bike'): 2,
    (1, 2, 'bike'): 1, (1, 3, 'bike'): 1, (2, 3, 'bike'): 1,
    (2, 1, 'bike'): 1, (3, 1, 'bike'): 1, (3, 2, 'bike'): 1,
}

# Visit times per vehicle
tv_j_s_v = {
    (0, 'car'): 0, (1, 'car'): 1, (2, 'car'): 1, (3, 'car'): 1,
    (0, 'bike'): 0, (1, 'bike'): 1, (2, 'bike'): 1, (3, 'bike'): 1,
}

# %%
# === Compute q_j for each j: average t_{i→j} over all i plus service time at j ===
q_j = {}
for j in A_s:
    # collect all travel times into j (across all vehicles if multimodal; here single 'car')
    incoming = [
        t_ij_s_v[(i, j, v)]
        for i in A_s for v in V
        if i != j and (i, j, v) in t_ij_s_v
    ]
    if incoming:
        avg_travel = sum(incoming) / len(incoming)
        # service time at j: pick any vehicle (service is vehicle-specific)
        # here: tv_j_s_v[(j, v)] is the same for all v
        svc = tv_j_s_v[(j, V[0])]
        q_j[j] = avg_travel + svc
    else:
        q_j[j] = 0.0   # depot or isolated node

# %%
# === Model ===
model = gp.Model("MultimodalVehicleRouting")

# === Variables ===
x = model.addVars(A_s, A_s, T, V, vtype=GRB.BINARY, name="x")
X = model.addVars(T, V, vtype=GRB.INTEGER, name="X")  # Trips from depot per vehicle
u = model.addVars(A_s, V, vtype=GRB.CONTINUOUS, name="u")

# === Objective ===
model.setObjective(
    gp.quicksum(x[i, j, t, v] / t_ij_s_v[i, j, v]
                for i in A_s for j in A_s for t in T for v in V
                if i != j and (i, j, v) in t_ij_s_v),
    GRB.MAXIMIZE
)

# %%
# === Constraints ===

# No self-loops
model.addConstrs(
    (gp.quicksum(x[i, i, t, v] for t in T for v in V) == 0 for i in A_s),
    name="NoSelfLoops"
)

# Flow conservation
model.addConstrs((
    gp.quicksum(x[i, j, t, v] for i in A_s if (i, j, v) in t_ij_s_v) ==
    gp.quicksum(x[j, i, t, v] for i in A_s if (j, i, v) in t_ij_s_v)
    for j in A_s for t in T for v in V), name="FlowConservation"
)

# One visit per node (excluding depot)
model.addConstrs((
    gp.quicksum(x[i, j, t, v]
                for t in T for v in V for i in A_s
                if i != j and (i, j, v) in t_ij_s_v) <= 1
    for j in A_s if j != 0), name="OneVisit"
)

# Depot departure matches X[t, v]
model.addConstrs((
    gp.quicksum(x[0, j, t, v] for j in A_s if j != 0 and (0, j, v) in t_ij_s_v) == X[t, v]
    for t in T for v in V), name="DepotStarts"
)

# Time budget constraint for each vehicle per day
model.addConstrs((
    gp.quicksum(x[i, j, t, v] * (t_ij_s_v[i, j, v] + tv_j_s_v[j, v])
                for i in A_s for j in A_s if i != j and (i, j, v) in t_ij_s_v) <= Q_v[v]
    for t in T for v in V), name="TimeBudget"
)

# Monotonicity: Xt,v ≥ Xt+1,v
model.addConstrs((
    X[t1, v] >= X[t2, v] for t1, t2 in zip(T[:-1], T[1:]) for v in V
), name="MonotonicTrips"
)

# Sub-tour Elimination Constraints (MTZ-like)
model.addConstrs((
    u[i, v] - u[j, v] + Q_v[v] * (1 - x[i, j, t, v]) >= 0
    for i in A_s for j in A_s if i != j
    for t in T for v in V if (i, j, v) in t_ij_s_v
), name="MTZ1"
)

model.addConstrs((
    u[j, v] >= t_ij_s_v[i, j, v]
    for i in A_s for j in A_s if j != 0
    for t in T for v in V if (i, j, v) in t_ij_s_v
), name="MTZ2"
)

model.addConstrs((u[i, v] <= Q_v[v] for i in A_s for v in V), name="MaxTime")
# Out:
# {(0, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (2, 'bike'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 'car'): <gurobi.Constr *Awaiting Model Update*>,
#  (3, 'bike'): <gurobi.Constr *Awaiting Model Update*>}

# %%
# === Solve ===
model.optimize()
# Out:
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i3-1115G4 @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 2 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 125 rows, 76 columns and 404 nonzeros
# Model fingerprint: 0x71a88bda
# Variable types: 8 continuous, 68 integer (64 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e-01, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e-01, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 52 rows and 20 columns
# Presolve time: 0.00s
# Presolved: 73 rows, 56 columns, 348 nonzeros
# Variable types: 8 continuous, 48 integer (48 binary)
#
# Root relaxation: objective 6.000000e+00, 10 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# ...

# %%
# === Output Solution as Full Routes ===
if model.status == GRB.OPTIMAL:
    print(f"\n✅ Optimal Objective Value: {model.objVal:.2f}\n")
    for t in T:
        for v in V:
            # collect chosen arcs for this day & vehicle
            arcs = [(i, j) for i in A_s for j in A_s
                    if i != j and (i, j, v) in t_ij_s_v and x[i, j, t, v].X > 0.5]
            # build a mapping from each i -> j
            succ = {i: j for i, j in arcs}
            # start at depot
            route = [0]
            curr = 0
            # follow until back to depot or stuck
            while curr in succ:
                nxt = succ[curr]
                route.append(nxt)
                curr = nxt
                if curr == 0:
                    break
            # pretty-print
            route_str = " → ".join(str(n) for n in route)
            print(f"Day {t}, Vehicle {v}: {route_str}")
else:
    print("❌ No optimal solution found.")
# Out:
# ✅ Optimal Objective Value: 6.00
#
# Day 1, Vehicle car: 0 → 1 → 3 → 0
# Day 1, Vehicle bike: 0
# Day 2, Vehicle car: 0 → 2 → 0
# Day 2, Vehicle bike: 0
